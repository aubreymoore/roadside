# %% [markdown]
# # get-random-bounding-boxes
#
# Aubrey Moore 2020-07-18
#
# Extracts a random set of images contained in bounded boxes for each label.
#
# Run using papermill using something like the following. Results will be in the HTML file.
# ```
# papermill --prepare-only get-random-bounding-boxes.ipynb reports/job27.ipynb -y '{"NSAMPLES":"10"}' && jupyter nbconvert --execute --to html reports/job27.ipynb
# ```

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import cv2
from pathlib import Path
import sys
import glob
import numpy as np
import shutil
from IPython.display import HTML, Image

# %%
DATADIR = '/media/aubrey/9C33-6BBD/job27'
CVATXMLFILE = 'DONT-ANNOTATE-06-25-2020-115358-5.xml'
VIDEOFILE = '20200625_115358_processed.mp4'
NSAMPLES = '10'

# %%
def _src_from_data(data):
    """Base64 encodes image bytes for inclusion in an HTML img element"""
    img_obj = Image(data=data)
    for bundle in img_obj._repr_mimebundle_():
        for mimetype, b64value in bundle.items():
            if mimetype.startswith('image/'):
                return f'data:{mimetype};base64,{b64value}'

def gallery(images, row_height='auto'):
    """Shows a set of images in a gallery that flexes with the width of the notebook.
    
    Parameters
    ----------
    images: list of str or bytes
        URLs or bytes of images to display

    row_height: str
        CSS height value to assign to all images. Set to 'auto' by default to show images
        with their native dimensions. Set to a value like '250px' to make all rows
        in the gallery equal height.
    """
    figures = []
    for image in images:
        if isinstance(image, bytes):
            src = _src_from_data(image)
            caption = ''
        else:
            src = image
            caption = f'<figcaption style="font-size: 0.6em">{image}</figcaption>'
        figures.append(f'''
            <figure style="margin: 5px !important;">
              <img src="{src}" style="height: {row_height}">
              {caption}
            </figure>
        ''')
    return HTML(data=f'''
        <div style="display: flex; flex-flow: row wrap; text-align: center;">
        {''.join(figures)}
        </div>
    ''')

# %%
def str2int(s):
    return int(float(s))

# str2int('7.53')

# %%
ET.tostring?

# %%
def get_bounding_boxes(xml_file):
    """
    Returns a pandas dataframe.
    """   
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    print(ET.tostring(root.find('meta'), encoding='unicode'))

    mylist = []
    for track in root.findall('track'):
        for box in track.findall('box'):
            mydict = box.attrib
            mydict.update(track.attrib)
            mylist.append(mydict)
    df = pd.DataFrame(mylist)
    df = df[(df.occluded=='0') & (df.outside=='0')]
    df.drop(['occluded', 'outside'], axis=1, inplace=True)
    df.rename({'id': 'track_id'}, axis=1, inplace=True)
    df.xbr = df.xbr.apply(lambda x: str2int(x))
    df.xtl = df.xtl.apply(lambda x: str2int(x))
    df.ybr = df.ybr.apply(lambda x: str2int(x))
    df.ytl = df.ytl.apply(lambda x: str2int(x))
    df.frame = df.frame.apply(lambda x: str2int(x))
    df.track_id = df.track_id.apply(lambda x: str2int(x))
    return df

#get_bounding_boxes(f'{DATADIR}/{CVATXMLFILE}')
# Out:
# <meta>
#     <task>
#       <id>27</id>
#       <name>DONT-ANNOTATE-06-25-2020-115358-5</name>
#       <size>489</size>
#       <mode>interpolation</mode>
#       <overlap>5</overlap>
#       <bugtracker />
#       <created>2020-07-16 16:03:29.955417+00:00</created>
#       <updated>2020-07-16 16:15:09.647745+00:00</updated>
#       <start_frame>0</start_frame>
#       <stop_frame>488</stop_frame>
#       <frame_filter />
#       <z_order>False</z_order>
#       <labels>
#         <label>
#           <name>zero</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>light</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>medium</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>high</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>non_recoverable</name>
#           <attributes>
#           </attributes>
#         </label>
#       </labels>
#       <segments>
#         <segment>
#           <id>27</id>
#           <start>0</start>
#           <stop>488</stop>
#           <url>http://cvat-5-classes--crb.cnas-re-uog.onepanel.io/?id=27</url>
#         </segment>
#       </segments>
#       <owner>
#         <username>admin</username>
#         <email />
#       </owner>
#       <assignee />
#       <original_size>
#         <width>2288</width>
#         <height>1080</height>
#       </original_size>
#     </task>
#     <dumped>2020-07-18 01:15:25.170090+00:00</dumped>
#     <source>20200625_115358_processed.mp4</source>
#   </meta>
#       frame keyframe   xtl  ytl   xbr  ybr  track_id  label
# 0        12        1   354  339   574  463         0  light
# 2        14        1   375  335   555  460         1  light
# 4        17        1   393  341   613  474         2  light
# 6        20        1   779  359   994  520         3   zero
# 8        20        1   962  364  1091  467         4  light
# ...     ...      ...   ...  ...   ...  ...       ...    ...
# 1294    482        1  1476  258  1635  529       647  light
# 1296    483        1  1478  255  1632  544       648  light
# 1298    484        1  1479  259  1635  542       649  light
# 1300    485        1  1479  260  1640  530       650  light
# 1302    486        1  1481  255  1634  538       651  light
#
# [652 rows x 8 columns]

# %%
def show_gallery(label):
    images = glob.glob(f'{label}*.jpg')
    print(images)
    gallery(images)

# %% [markdown]
# # MAIN

# %%
dfbb = get_bounding_boxes(f'{DATADIR}/{CVATXMLFILE}')

# Extract random image samples for each damage level label and write these to jpg image files.
        
cap = cv2.VideoCapture(f'{DATADIR}/{VIDEOFILE}')
grouped = dfbb.groupby('label')
print(grouped.size())
for name, df in grouped:
    n = min(int(NSAMPLES), df.shape[0]) # get min of row count or NSAMPLES 
    for i, r in df.sample(n).iterrows():
        cap.set(1, r.frame)
        _, frame = cap.read()
        img = frame[r.ytl:r.ybr, r.xtl:r.xbr]
        cv2.imwrite(f'{r.label}t{r.track_id:04d}f{r.frame:04d}.jpg', img)
cap.release()
# Out:
# <meta>
#     <task>
#       <id>27</id>
#       <name>DONT-ANNOTATE-06-25-2020-115358-5</name>
#       <size>489</size>
#       <mode>interpolation</mode>
#       <overlap>5</overlap>
#       <bugtracker />
#       <created>2020-07-16 16:03:29.955417+00:00</created>
#       <updated>2020-07-16 16:15:09.647745+00:00</updated>
#       <start_frame>0</start_frame>
#       <stop_frame>488</stop_frame>
#       <frame_filter />
#       <z_order>False</z_order>
#       <labels>
#         <label>
#           <name>zero</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>light</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>medium</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>high</name>
#           <attributes>
#           </attributes>
#         </label>
#         <label>
#           <name>non_recoverable</name>
#           <attributes>
#           </attributes>
#         </label>
#       </labels>
#       <segments>
#         <segment>
#           <id>27</id>
#           <start>0</start>
#           <stop>488</stop>
#           <url>http://cvat-5-classes--crb.cnas-re-uog.onepanel.io/?id=27</url>
#         </segment>
#       </segments>
#       <owner>
#         <username>admin</username>
#         <email />
#       </owner>
#       <assignee />
#       <original_size>
#         <width>2288</width>
#         <height>1080</height>
#       </original_size>
#     </task>
#     <dumped>2020-07-18 01:15:25.170090+00:00</dumped>
#     <source>20200625_115358_processed.mp4</source>
#   </meta>
#
# label
# high        4
# light     353
# medium     70
# zero      225
# dtype: int64

# %% [markdown]
# # Zero damage

# %%
gallery(glob.glob('zero*.jpg'))
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0064f0126.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0064f0126.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0019f0026.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0019f0026.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0140f0141.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0140f0141.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0129f0138.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0129f0138.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0139f0141.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0139f0141.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0025f0034.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0025f0034.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0204f0157.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0204f0157.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0086f0131.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0086f0131.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0138f0141.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0138f0141.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0483f0396.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0483f0396.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0093f0133.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0093f0133.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0413f0385.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0413f0385.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0096f0133.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0096f0133.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0136f0140.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0136f0140.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0192f0155.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0192f0155.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0098f0134.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0098f0134.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0512f0401.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0512f0401.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0068f0127.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0068f0127.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0151f0144.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0151f0144.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="zerot0559f0409.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">zerot0559f0409.jpg</figcaption>
#             </figure>
#
#         </div>

# %% [markdown]
# # Light damage

# %%
gallery(glob.glob('light*.jpg'))
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0010f0023.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0010f0023.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0382f0378.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0382f0378.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0628f0435.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0628f0435.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0076f0128.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0076f0128.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0370f0373.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0370f0373.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0462f0393.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0462f0393.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0329f0281.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0329f0281.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0365f0354.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0365f0354.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0379f0377.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0379f0377.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0651f0486.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0651f0486.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0222f0163.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0222f0163.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0625f0434.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0625f0434.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0445f0390.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0445f0390.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0043f0043.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0043f0043.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0485f0397.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0485f0397.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0380f0378.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0380f0378.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0042f0043.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0042f0043.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0539f0405.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0539f0405.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0353f0334.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0353f0334.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="lightt0478f0396.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">lightt0478f0396.jpg</figcaption>
#             </figure>
#
#         </div>

# %% [markdown]
# # Medium damage

# %%
gallery(glob.glob('medium*.jpg'))
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0237f0175.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0237f0175.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0252f0183.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0252f0183.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0271f0246.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0271f0246.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0322f0273.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0322f0273.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0633f0444.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0633f0444.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0352f0304.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0352f0304.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0289f0256.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0289f0256.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0258f0186.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0258f0186.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0067f0127.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0067f0127.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0239f0178.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0239f0178.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0294f0258.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0294f0258.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0323f0274.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0323f0274.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0247f0182.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0247f0182.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0259f0187.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0259f0187.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0330f0282.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0330f0282.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0598f0422.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0598f0422.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0256f0184.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0256f0184.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0265f0208.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0265f0208.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0308f0263.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0308f0263.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="mediumt0296f0258.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">mediumt0296f0258.jpg</figcaption>
#             </figure>
#
#         </div>

# %% [markdown]
# # High damage

# %%
gallery(glob.glob('high*.jpg'))
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="hight0309f0264.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">hight0309f0264.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="hight0310f0265.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">hight0310f0265.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="hight0278f0249.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">hight0278f0249.jpg</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="hight0293f0257.jpg" style="height: auto">
#               <figcaption style="font-size: 0.6em">hight0293f0257.jpg</figcaption>
#             </figure>
#
#         </div>

# %% [markdown]
# # Non-recoverable damage

# %%
gallery(glob.glob('non_recoverable*.jpg'))
# Out:
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#         </div>
