# %% [raw]
# """
#
# 2021-04-21 Changed 'INSERT' to 'INSERT OR IGNORE'
#
# 2021-01-25 Silent error handling added when there is no corresponding record in frames table.
#
#
# 2021-01-04 Modified by Aubrey Moore
#
# Enters object detector results from CVAT XML files into the survey database.
# Data are inserted into the trees and vcuts tables.
#
# The CVAT XML files contain data which looks like this:
#
#   <image id="3280" name="frame_003280" width="1920" height="1080">
#     <box label="zero" occluded="0" xtl="474.00" ytl="836.00" xbr="636.00" ybr="1070.00">
#     </box>
#     <box label="zero" occluded="0" xtl="0.00" ytl="895.00" xbr="264.00" ybr="1077.00">
#     </box>
#     <box label="light" occluded="0" xtl="1395.00" ytl="235.00" xbr="1918.00" ybr="918.00">
#     </box>
#     <box label="light" occluded="0" xtl="677.00" ytl="734.00" xbr="894.00" ybr="1029.00">
#     </box>
#
#   <image id="3280" name="frame_003280" width="1920" height="1080">
#     <polygon label="cut" occluded="0" points="805.00,762.50;796.00,762.50;792.50,754.00;804.00,736.50;813.00,734.50;814.50,747.00;805.00,762.50">
#     </polygon>
#
#
# """

# %%
#import plac
import spatialite
# import glob
import os
import xml.etree.ElementTree as ET
# import pandas as pd
# import logging

# %%
def main(cvatxml_path, db_path):
    conn = spatialite.connect(db_path)
    cursor = conn.cursor()

    damagedict = {'zero': 0, 'light': 1, 'medium': 2, 'high': 3, 'non_recoverable': 4}

    # Get the video_id from the name field of the videos table
    video = os.path.basename(cvatxml_path).replace('.xml', '.mp4')
    sql = (f'SELECT id FROM videos WHERE name = "{video}"')
    cursor.execute(sql)
    video_id = cursor.fetchone()[0]

    # Iterate through the XML tree, entering records into the trees and vcuts database tables
    root = ET.parse(cvatxml_path).getroot()
    for image in root.iter('image'):
        frame_number = int(image.attrib['id'])
        sql = f'SELECT id FROM frames WHERE video_id={video_id} AND frame_number={frame_number};'
        cursor.execute(sql)

        #frame_id = cursor.fetchone()[0]
        data = cursor.fetchone()
        if data is None:
            print(f'ERROR: No data returned by "{sql}"')
        else:
            frame_id = data[0]
            for box in image.iter('box'):
                damage_index_text = box.attrib['label']
                damage_index = damagedict[damage_index_text]
                xtl = int(float(box.attrib['xtl']))
                ytl = int(float(box.attrib['ytl']))
                xbr = int(float(box.attrib['xbr']))
                ybr = int(float(box.attrib['ybr']))
                geometry = f'GeomFromText("MULTIPOINT({xtl} {ytl},{xbr} {ybr})", -1)'
                sql = f'INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES ({frame_id},{damage_index},{geometry});'
                print(sql)
                cursor.execute(sql)
                conn.commit()
            for polygon in image.iter('polygon'):
                points = polygon.attrib['points']
                points = points.replace(',', ' ').replace(';', ',') # Reformat points to match WKT for a polygon
                geometry = f'PolyFromText("POLYGON(({points}))",-1)'
                sql = f'INSERT OR IGNORE INTO vcuts(frame_id,geometry) VALUES({frame_id},{geometry});'
                cursor.execute(sql)
                conn.commit()
    cursor.close()
    conn.close()

# %% [raw]
# if __name__ == '__main__':
#     import plac
#     plac.call(main)

# %%
# MAIN

cvatxml_path = '../output/20210308_131427.xml'
db_path = '../output/Guam03.db'

assert os.path.exists(cvatxml_path), f'Cannot find {cvatxml_path}'
assert os.path.exists(db_path), f'Cannot find {db_path}'
main(cvatxml_path, db_path)
# Out:
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151462,1,GeomFromText("MULTIPOINT(351 869,472 958)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151467,0,GeomFromText("MULTIPOINT(0 727,195 986)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151472,0,GeomFromText("MULTIPOINT(0 673,340 1012)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151472,1,GeomFromText("MULTIPOINT(573 818,751 945)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151477,0,GeomFromText("MULTIPOINT(150 612,582 1006)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151477,0,GeomFromText("MULTIPOINT(728 784,917 938)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151477,1,GeomFromText("MULTIPOINT(146 616,585 1012)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151482,0,GeomFromText("MULTIPOINT(356 526,852 1024)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151482,1,GeomFromText("MULTIPOINT(875 771,1150 953)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151487,0,GeomFromText("MULTIPOINT(1135 737,1439 967)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151487,1,GeomFromText("MULTIPOINT(708 454,1237 1051)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151492,1,GeomFromText("MULTIPOINT(1197 308,1892 1070)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151542,0,GeomFromText("MULTIPOINT(78 502,248 644)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151577,1,GeomFromText("MULTIPOINT(19 788,186 908)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151582,3,GeomFromText("MULTIPOINT(449 373,608 729)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151612,3,GeomFromText("MULTIPOINT(1326 457,1684 888)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151637,1,GeomFromText("MULTIPOINT(1395 665,1568 824)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151642,1,GeomFromText("MULTIPOINT(1547 657,1720 814)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151647,1,GeomFromText("MULTIPOINT(1704 633,1910 832)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151647,1,GeomFromText("MULTIPOINT(1167 795,1258 883)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151657,1,GeomFromText("MULTIPOINT(1417 796,1505 888)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151657,1,GeomFromText("MULTIPOINT(1694 792,1883 900)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151742,3,GeomFromText("MULTIPOINT(199 257,388 926)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151747,3,GeomFromText("MULTIPOINT(460 187,648 804)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151752,3,GeomFromText("MULTIPOINT(787 49,1029 956)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151757,1,GeomFromText("MULTIPOINT(1011 427,1500 982)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151797,1,GeomFromText("MULTIPOINT(295 553,598 867)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151802,1,GeomFromText("MULTIPOINT(410 488,743 869)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151807,1,GeomFromText("MULTIPOINT(513 450,877 902)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151817,1,GeomFromText("MULTIPOINT(759 408,1138 932)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151822,1,GeomFromText("MULTIPOINT(899 390,1354 1004)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151832,1,GeomFromText("MULTIPOINT(1202 378,1628 998)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151837,1,GeomFromText("MULTIPOINT(1321 343,1913 1020)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (151842,1,GeomFromText("MULTIPOINT(1468 324,1920 1050)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152252,1,GeomFromText("MULTIPOINT(426 721,576 965)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152257,1,GeomFromText("MULTIPOINT(641 715,797 936)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152262,1,GeomFromText("MULTIPOINT(864 710,1017 938)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152267,1,GeomFromText("MULTIPOINT(1099 697,1275 907)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152267,1,GeomFromText("MULTIPOINT(1253 702,1370 875)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152272,1,GeomFromText("MULTIPOINT(1529 673,1694 898)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152272,1,GeomFromText("MULTIPOINT(1372 672,1564 883)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152277,1,GeomFromText("MULTIPOINT(1677 634,1906 886)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152282,1,GeomFromText("MULTIPOINT(237 639,332 728)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152287,1,GeomFromText("MULTIPOINT(0 478,234 880)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152292,1,GeomFromText("MULTIPOINT(114 478,443 913)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152292,1,GeomFromText("MULTIPOINT(0 485,182 801)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152297,1,GeomFromText("MULTIPOINT(254 476,578 925)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152297,1,GeomFromText("MULTIPOINT(28 483,311 885)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152297,2,GeomFromText("MULTIPOINT(265 461,578 886)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152302,1,GeomFromText("MULTIPOINT(388 447,716 934)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152307,2,GeomFromText("MULTIPOINT(506 411,844 997)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152312,1,GeomFromText("MULTIPOINT(614 381,976 1001)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152312,1,GeomFromText("MULTIPOINT(1240 643,1464 909)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152312,1,GeomFromText("MULTIPOINT(1107 616,1311 920)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152312,2,GeomFromText("MULTIPOINT(616 373,984 992)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152317,0,GeomFromText("MULTIPOINT(1307 641,1569 915)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152317,2,GeomFromText("MULTIPOINT(722 351,1136 1006)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152322,1,GeomFromText("MULTIPOINT(827 310,1286 1022)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152327,2,GeomFromText("MULTIPOINT(984 279,1470 1011)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152327,0,GeomFromText("MULTIPOINT(1477 625,1746 926)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152332,2,GeomFromText("MULTIPOINT(1141 193,1715 989)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152337,2,GeomFromText("MULTIPOINT(1338 89,1920 967)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152342,1,GeomFromText("MULTIPOINT(926 146,1658 1059)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152347,1,GeomFromText("MULTIPOINT(743 36,1681 1006)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152487,3,GeomFromText("MULTIPOINT(1155 527,1286 803)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152492,3,GeomFromText("MULTIPOINT(1292 498,1434 856)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152497,2,GeomFromText("MULTIPOINT(1451 466,1605 734)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152502,3,GeomFromText("MULTIPOINT(1625 416,1806 727)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152512,3,GeomFromText("MULTIPOINT(760 639,865 750)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152607,0,GeomFromText("MULTIPOINT(582 851,831 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152617,0,GeomFromText("MULTIPOINT(32 833,255 1024)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152622,0,GeomFromText("MULTIPOINT(398 814,727 1063)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152622,0,GeomFromText("MULTIPOINT(124 832,374 1061)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152622,0,GeomFromText("MULTIPOINT(648 832,857 1058)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152627,0,GeomFromText("MULTIPOINT(121 837,297 1045)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152627,0,GeomFromText("MULTIPOINT(9 837,192 1032)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152627,0,GeomFromText("MULTIPOINT(33 840,240 1044)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152627,0,GeomFromText("MULTIPOINT(746 799,1093 1067)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152627,0,GeomFromText("MULTIPOINT(277 821,500 1072)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152627,0,GeomFromText("MULTIPOINT(619 822,821 1079)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152632,0,GeomFromText("MULTIPOINT(1102 800,1415 1066)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152637,0,GeomFromText("MULTIPOINT(443 836,650 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152637,0,GeomFromText("MULTIPOINT(294 862,518 1077)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152637,0,GeomFromText("MULTIPOINT(111 830,338 1063)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152642,0,GeomFromText("MULTIPOINT(477 852,770 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152642,0,GeomFromText("MULTIPOINT(683 831,930 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152647,0,GeomFromText("MULTIPOINT(755 839,977 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152652,0,GeomFromText("MULTIPOINT(1112 828,1526 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152657,1,GeomFromText("MULTIPOINT(437 698,866 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152657,0,GeomFromText("MULTIPOINT(1630 833,1917 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152662,0,GeomFromText("MULTIPOINT(105 790,412 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152667,0,GeomFromText("MULTIPOINT(334 787,613 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152672,0,GeomFromText("MULTIPOINT(869 829,1148 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152672,0,GeomFromText("MULTIPOINT(241 840,566 1074)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152672,0,GeomFromText("MULTIPOINT(579 757,933 1070)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152677,0,GeomFromText("MULTIPOINT(346 827,604 1066)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152677,0,GeomFromText("MULTIPOINT(492 845,768 1079)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152682,0,GeomFromText("MULTIPOINT(189 840,450 1079)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152682,0,GeomFromText("MULTIPOINT(612 821,881 1058)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152687,0,GeomFromText("MULTIPOINT(390 834,637 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152687,0,GeomFromText("MULTIPOINT(260 829,482 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152687,0,GeomFromText("MULTIPOINT(1007 809,1304 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152692,0,GeomFromText("MULTIPOINT(884 822,1094 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152697,0,GeomFromText("MULTIPOINT(744 791,1128 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152697,0,GeomFromText("MULTIPOINT(1036 789,1377 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152702,0,GeomFromText("MULTIPOINT(747 870,997 1071)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152702,0,GeomFromText("MULTIPOINT(383 799,755 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152702,0,GeomFromText("MULTIPOINT(1651 770,1920 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152702,0,GeomFromText("MULTIPOINT(1198 774,1686 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152702,0,GeomFromText("MULTIPOINT(940 825,1294 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152707,0,GeomFromText("MULTIPOINT(1299 812,1616 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152712,0,GeomFromText("MULTIPOINT(683 863,922 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152717,0,GeomFromText("MULTIPOINT(67 644,365 1072)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152722,0,GeomFromText("MULTIPOINT(582 752,1028 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152732,1,GeomFromText("MULTIPOINT(949 478,1417 1064)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152737,1,GeomFromText("MULTIPOINT(99 592,440 1045)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152737,0,GeomFromText("MULTIPOINT(765 593,1262 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152752,0,GeomFromText("MULTIPOINT(1169 765,1448 1043)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152757,0,GeomFromText("MULTIPOINT(1519 796,1786 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152757,0,GeomFromText("MULTIPOINT(199 751,600 1057)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152762,0,GeomFromText("MULTIPOINT(9 815,218 1006)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152762,0,GeomFromText("MULTIPOINT(528 736,875 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152762,0,GeomFromText("MULTIPOINT(349 805,567 1047)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152762,1,GeomFromText("MULTIPOINT(193 865,330 1018)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152767,1,GeomFromText("MULTIPOINT(351 860,517 1031)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152767,0,GeomFromText("MULTIPOINT(586 821,812 1069)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152767,0,GeomFromText("MULTIPOINT(134 808,336 1018)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152767,0,GeomFromText("MULTIPOINT(780 768,1030 1058)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152772,2,GeomFromText("MULTIPOINT(12 775,189 985)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152772,0,GeomFromText("MULTIPOINT(871 822,1182 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152772,0,GeomFromText("MULTIPOINT(246 792,496 1041)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152772,0,GeomFromText("MULTIPOINT(1187 760,1508 1076)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152772,0,GeomFromText("MULTIPOINT(1506 812,1841 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152772,1,GeomFromText("MULTIPOINT(564 868,733 1067)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152777,2,GeomFromText("MULTIPOINT(134 773,346 1015)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152777,0,GeomFromText("MULTIPOINT(850 882,1061 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152777,0,GeomFromText("MULTIPOINT(1334 768,1739 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152777,0,GeomFromText("MULTIPOINT(415 792,676 1059)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152782,0,GeomFromText("MULTIPOINT(1264 875,1530 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152782,0,GeomFromText("MULTIPOINT(685 774,944 1063)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152782,1,GeomFromText("MULTIPOINT(263 750,457 1016)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152787,0,GeomFromText("MULTIPOINT(1018 747,1294 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152792,0,GeomFromText("MULTIPOINT(697 722,979 1041)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152797,1,GeomFromText("MULTIPOINT(982 668,1382 1076)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152802,1,GeomFromText("MULTIPOINT(1457 619,1892 1075)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152812,1,GeomFromText("MULTIPOINT(1259 848,1331 913)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152812,1,GeomFromText("MULTIPOINT(1134 812,1220 913)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152817,2,GeomFromText("MULTIPOINT(1188 805,1261 916)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152822,2,GeomFromText("MULTIPOINT(1250 798,1317 908)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152832,0,GeomFromText("MULTIPOINT(905 760,1061 927)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152837,3,GeomFromText("MULTIPOINT(928 658,1051 763)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152842,1,GeomFromText("MULTIPOINT(1499 789,1595 908)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152847,1,GeomFromText("MULTIPOINT(1233 745,1447 904)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152847,1,GeomFromText("MULTIPOINT(1585 788,1659 897)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152852,2,GeomFromText("MULTIPOINT(1664 784,1743 901)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152852,1,GeomFromText("MULTIPOINT(1382 735,1608 922)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152852,1,GeomFromText("MULTIPOINT(1591 804,1676 901)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152857,1,GeomFromText("MULTIPOINT(1543 725,1766 913)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152862,1,GeomFromText("MULTIPOINT(1699 710,1917 900)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152867,1,GeomFromText("MULTIPOINT(1788 796,1861 914)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (152932,1,GeomFromText("MULTIPOINT(558 741,754 916)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153097,0,GeomFromText("MULTIPOINT(306 776,400 850)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153132,0,GeomFromText("MULTIPOINT(125 750,232 891)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153387,0,GeomFromText("MULTIPOINT(137 766,230 885)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153412,0,GeomFromText("MULTIPOINT(139 765,231 876)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153417,0,GeomFromText("MULTIPOINT(138 762,226 876)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153427,0,GeomFromText("MULTIPOINT(346 796,433 861)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153467,0,GeomFromText("MULTIPOINT(137 768,233 880)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153507,1,GeomFromText("MULTIPOINT(605 793,646 834)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153512,1,GeomFromText("MULTIPOINT(613 791,652 833)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153517,1,GeomFromText("MULTIPOINT(619 791,662 829)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153522,1,GeomFromText("MULTIPOINT(633 789,675 828)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153592,1,GeomFromText("MULTIPOINT(813 785,857 819)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153597,1,GeomFromText("MULTIPOINT(821 789,863 821)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153607,1,GeomFromText("MULTIPOINT(845 787,887 817)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153687,2,GeomFromText("MULTIPOINT(1 542,187 708)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (153802,1,GeomFromText("MULTIPOINT(276 597,396 812)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154127,1,GeomFromText("MULTIPOINT(1 527,374 947)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154127,1,GeomFromText("MULTIPOINT(6 376,191 564)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154132,0,GeomFromText("MULTIPOINT(0 510,512 931)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154137,1,GeomFromText("MULTIPOINT(24 479,539 928)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154142,1,GeomFromText("MULTIPOINT(171 416,776 938)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154152,2,GeomFromText("MULTIPOINT(347 176,654 506)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154157,2,GeomFromText("MULTIPOINT(394 124,770 755)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154157,0,GeomFromText("MULTIPOINT(526 292,1236 976)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154172,1,GeomFromText("MULTIPOINT(1272 31,1920 1062)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154172,1,GeomFromText("MULTIPOINT(772 14,1313 620)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154177,1,GeomFromText("MULTIPOINT(955 66,1605 858)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154182,1,GeomFromText("MULTIPOINT(1140 70,1891 957)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154262,1,GeomFromText("MULTIPOINT(670 649,830 824)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154267,1,GeomFromText("MULTIPOINT(6 654,195 894)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154282,1,GeomFromText("MULTIPOINT(92 694,157 756)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154287,1,GeomFromText("MULTIPOINT(176 677,252 755)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154287,1,GeomFromText("MULTIPOINT(95 690,165 756)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154292,1,GeomFromText("MULTIPOINT(165 676,248 763)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154292,1,GeomFromText("MULTIPOINT(86 692,152 763)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154297,1,GeomFromText("MULTIPOINT(135 672,223 748)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154297,1,GeomFromText("MULTIPOINT(49 687,122 754)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154302,1,GeomFromText("MULTIPOINT(1 681,79 755)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154302,1,GeomFromText("MULTIPOINT(99 667,177 745)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154307,1,GeomFromText("MULTIPOINT(48 658,137 738)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154312,1,GeomFromText("MULTIPOINT(0 647,88 747)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154312,1,GeomFromText("MULTIPOINT(451 481,738 886)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154317,1,GeomFromText("MULTIPOINT(532 442,854 879)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154322,1,GeomFromText("MULTIPOINT(635 392,1001 849)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154327,1,GeomFromText("MULTIPOINT(736 347,1186 936)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154332,1,GeomFromText("MULTIPOINT(882 307,1461 925)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154337,1,GeomFromText("MULTIPOINT(1084 231,1671 879)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154342,1,GeomFromText("MULTIPOINT(1342 125,1915 924)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154412,2,GeomFromText("MULTIPOINT(522 617,586 749)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154417,1,GeomFromText("MULTIPOINT(509 618,577 753)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154422,1,GeomFromText("MULTIPOINT(503 615,562 747)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154427,1,GeomFromText("MULTIPOINT(485 608,552 756)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154482,1,GeomFromText("MULTIPOINT(696 542,795 729)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154487,1,GeomFromText("MULTIPOINT(720 534,803 697)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154492,4,GeomFromText("MULTIPOINT(1094 616,1110 681)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154492,1,GeomFromText("MULTIPOINT(751 526,828 693)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154497,4,GeomFromText("MULTIPOINT(1113 574,1145 688)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154497,4,GeomFromText("MULTIPOINT(1114 581,1156 698)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154502,1,GeomFromText("MULTIPOINT(0 268,224 644)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154507,1,GeomFromText("MULTIPOINT(0 165,308 838)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154512,2,GeomFromText("MULTIPOINT(0 61,450 980)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154512,1,GeomFromText("MULTIPOINT(6 56,438 891)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154517,1,GeomFromText("MULTIPOINT(24 0,652 901)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154557,4,GeomFromText("MULTIPOINT(1061 502,1103 651)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154562,4,GeomFromText("MULTIPOINT(1134 486,1171 630)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154567,4,GeomFromText("MULTIPOINT(1205 480,1252 631)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154587,4,GeomFromText("MULTIPOINT(1639 397,1706 559)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154672,0,GeomFromText("MULTIPOINT(1270 480,1448 725)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154762,1,GeomFromText("MULTIPOINT(0 123,259 372)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154762,0,GeomFromText("MULTIPOINT(0 125,252 371)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154792,1,GeomFromText("MULTIPOINT(1163 787,1302 905)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (154832,1,GeomFromText("MULTIPOINT(536 0,1239 1022)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155067,3,GeomFromText("MULTIPOINT(963 671,1035 906)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155072,3,GeomFromText("MULTIPOINT(1352 497,1482 835)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155072,3,GeomFromText("MULTIPOINT(165 622,287 949)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155082,3,GeomFromText("MULTIPOINT(1156 301,1310 948)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155087,3,GeomFromText("MULTIPOINT(1360 236,1611 912)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155092,3,GeomFromText("MULTIPOINT(1621 176,1870 962)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155102,3,GeomFromText("MULTIPOINT(817 467,975 824)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155102,3,GeomFromText("MULTIPOINT(1090 451,1203 917)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155102,3,GeomFromText("MULTIPOINT(529 579,657 839)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155107,3,GeomFromText("MULTIPOINT(983 438,1183 955)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155107,3,GeomFromText("MULTIPOINT(1310 408,1445 918)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155122,3,GeomFromText("MULTIPOINT(950 488,1084 921)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155132,3,GeomFromText("MULTIPOINT(1607 637,1704 894)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155132,1,GeomFromText("MULTIPOINT(51 524,200 644)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155132,0,GeomFromText("MULTIPOINT(1157 431,1423 752)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155142,2,GeomFromText("MULTIPOINT(1621 331,1887 966)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155147,1,GeomFromText("MULTIPOINT(343 395,583 610)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155182,1,GeomFromText("MULTIPOINT(1142 599,1258 748)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155187,1,GeomFromText("MULTIPOINT(646 428,800 513)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155192,3,GeomFromText("MULTIPOINT(614 266,815 825)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155207,2,GeomFromText("MULTIPOINT(1480 6,1855 611)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155322,1,GeomFromText("MULTIPOINT(1222 743,1262 818)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155767,1,GeomFromText("MULTIPOINT(258 118,782 555)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155812,1,GeomFromText("MULTIPOINT(14 248,405 715)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155817,1,GeomFromText("MULTIPOINT(224 112,714 625)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155857,0,GeomFromText("MULTIPOINT(306 406,594 734)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155927,0,GeomFromText("MULTIPOINT(261 128,486 356)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (155932,0,GeomFromText("MULTIPOINT(135 107,488 616)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156322,1,GeomFromText("MULTIPOINT(155 164,482 577)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156542,1,GeomFromText("MULTIPOINT(737 0,1126 305)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156657,1,GeomFromText("MULTIPOINT(4 445,302 947)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156657,0,GeomFromText("MULTIPOINT(0 421,278 911)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156662,0,GeomFromText("MULTIPOINT(77 356,501 973)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156667,1,GeomFromText("MULTIPOINT(327 225,834 927)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156667,0,GeomFromText("MULTIPOINT(0 548,637 1035)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156682,1,GeomFromText("MULTIPOINT(1140 226,1894 1080)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156692,1,GeomFromText("MULTIPOINT(610 422,1195 929)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156697,1,GeomFromText("MULTIPOINT(1058 275,1862 1035)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156857,0,GeomFromText("MULTIPOINT(0 493,211 794)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156862,0,GeomFromText("MULTIPOINT(0 460,369 804)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156867,0,GeomFromText("MULTIPOINT(3 422,531 892)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156872,0,GeomFromText("MULTIPOINT(136 409,758 926)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156877,0,GeomFromText("MULTIPOINT(367 362,975 939)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156882,1,GeomFromText("MULTIPOINT(624 345,1259 879)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156887,0,GeomFromText("MULTIPOINT(52 752,230 894)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156887,1,GeomFromText("MULTIPOINT(886 296,1588 918)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156892,0,GeomFromText("MULTIPOINT(246 748,404 901)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156892,1,GeomFromText("MULTIPOINT(1176 263,1902 970)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156897,0,GeomFromText("MULTIPOINT(450 755,599 890)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156902,0,GeomFromText("MULTIPOINT(638 767,781 895)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156907,0,GeomFromText("MULTIPOINT(804 776,961 905)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156912,0,GeomFromText("MULTIPOINT(982 769,1134 899)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156917,0,GeomFromText("MULTIPOINT(1181 763,1339 898)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156917,1,GeomFromText("MULTIPOINT(1014 710,1111 791)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156922,1,GeomFromText("MULTIPOINT(1041 713,1145 801)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156922,0,GeomFromText("MULTIPOINT(1669 777,1802 907)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156927,1,GeomFromText("MULTIPOINT(1584 765,1770 920)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156932,1,GeomFromText("MULTIPOINT(1459 719,1571 814)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (156942,1,GeomFromText("MULTIPOINT(1714 714,1827 812)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157077,1,GeomFromText("MULTIPOINT(0 147,457 943)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157082,1,GeomFromText("MULTIPOINT(18 121,628 990)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157087,1,GeomFromText("MULTIPOINT(166 182,845 1017)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157092,1,GeomFromText("MULTIPOINT(276 173,1002 1031)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157092,0,GeomFromText("MULTIPOINT(12 172,510 860)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157097,1,GeomFromText("MULTIPOINT(445 56,1145 1026)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157102,1,GeomFromText("MULTIPOINT(614 18,1374 1043)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157107,1,GeomFromText("MULTIPOINT(838 0,1655 997)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157112,1,GeomFromText("MULTIPOINT(1055 0,1920 1032)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157127,1,GeomFromText("MULTIPOINT(969 0,1911 1020)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157137,0,GeomFromText("MULTIPOINT(281 299,889 1053)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157137,1,GeomFromText("MULTIPOINT(1326 0,1920 1039)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157142,1,GeomFromText("MULTIPOINT(5 512,253 977)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157147,0,GeomFromText("MULTIPOINT(1176 87,1865 985)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157147,0,GeomFromText("MULTIPOINT(780 288,1212 1042)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157147,1,GeomFromText("MULTIPOINT(95 529,517 1012)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157152,0,GeomFromText("MULTIPOINT(332 520,720 990)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157157,0,GeomFromText("MULTIPOINT(489 528,857 1010)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157157,0,GeomFromText("MULTIPOINT(940 238,1391 908)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157162,0,GeomFromText("MULTIPOINT(608 520,1025 1007)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157162,0,GeomFromText("MULTIPOINT(1113 227,1562 863)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157167,1,GeomFromText("MULTIPOINT(732 519,1104 996)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157172,1,GeomFromText("MULTIPOINT(799 514,1205 984)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157177,1,GeomFromText("MULTIPOINT(874 514,1282 1010)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157177,1,GeomFromText("MULTIPOINT(1389 212,1905 864)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157182,1,GeomFromText("MULTIPOINT(898 519,1313 1017)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157182,0,GeomFromText("MULTIPOINT(898 513,1310 1008)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157187,1,GeomFromText("MULTIPOINT(927 517,1323 1019)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157187,1,GeomFromText("MULTIPOINT(1486 205,1912 909)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157192,1,GeomFromText("MULTIPOINT(919 526,1320 1024)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157192,1,GeomFromText("MULTIPOINT(1462 198,1920 902)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157197,1,GeomFromText("MULTIPOINT(916 532,1327 1032)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157197,1,GeomFromText("MULTIPOINT(1473 218,1911 899)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157197,0,GeomFromText("MULTIPOINT(1292 580,1583 836)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157202,1,GeomFromText("MULTIPOINT(916 533,1323 1035)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157207,1,GeomFromText("MULTIPOINT(920 531,1318 1030)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157212,1,GeomFromText("MULTIPOINT(925 529,1321 1033)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157217,1,GeomFromText("MULTIPOINT(931 524,1316 1018)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157217,1,GeomFromText("MULTIPOINT(1454 220,1920 882)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157222,1,GeomFromText("MULTIPOINT(923 528,1313 1033)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157227,1,GeomFromText("MULTIPOINT(929 508,1333 1022)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157232,1,GeomFromText("MULTIPOINT(927 517,1329 1026)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157232,1,GeomFromText("MULTIPOINT(1458 222,1920 905)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157232,0,GeomFromText("MULTIPOINT(1280 587,1568 827)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157237,1,GeomFromText("MULTIPOINT(929 518,1328 1025)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157242,1,GeomFromText("MULTIPOINT(930 516,1338 1031)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157247,1,GeomFromText("MULTIPOINT(928 516,1342 1017)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157247,1,GeomFromText("MULTIPOINT(1452 216,1920 896)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157252,1,GeomFromText("MULTIPOINT(916 524,1333 1032)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157252,1,GeomFromText("MULTIPOINT(1442 217,1920 886)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157257,1,GeomFromText("MULTIPOINT(923 513,1339 1021)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157257,0,GeomFromText("MULTIPOINT(1460 221,1910 902)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157262,1,GeomFromText("MULTIPOINT(919 525,1327 1034)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157267,1,GeomFromText("MULTIPOINT(926 517,1322 1017)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157272,1,GeomFromText("MULTIPOINT(932 513,1331 1024)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157272,1,GeomFromText("MULTIPOINT(1461 176,1913 907)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157277,1,GeomFromText("MULTIPOINT(919 514,1323 1026)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157277,1,GeomFromText("MULTIPOINT(1472 219,1909 908)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157282,1,GeomFromText("MULTIPOINT(932 513,1334 1015)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157282,1,GeomFromText("MULTIPOINT(1441 201,1917 911)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157287,1,GeomFromText("MULTIPOINT(918 520,1323 1012)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157287,1,GeomFromText("MULTIPOINT(1441 199,1920 923)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157292,1,GeomFromText("MULTIPOINT(923 513,1327 1023)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157292,1,GeomFromText("MULTIPOINT(1444 193,1917 907)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157297,1,GeomFromText("MULTIPOINT(930 516,1320 1015)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157297,1,GeomFromText("MULTIPOINT(1437 199,1915 912)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157302,1,GeomFromText("MULTIPOINT(918 527,1328 1026)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157302,1,GeomFromText("MULTIPOINT(1448 210,1918 938)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157307,1,GeomFromText("MULTIPOINT(930 527,1329 1022)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157307,1,GeomFromText("MULTIPOINT(1496 192,1915 904)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157312,1,GeomFromText("MULTIPOINT(957 508,1358 1016)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157312,1,GeomFromText("MULTIPOINT(1493 226,1920 915)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157317,1,GeomFromText("MULTIPOINT(1529 188,1920 918)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157317,1,GeomFromText("MULTIPOINT(974 512,1396 1014)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157322,1,GeomFromText("MULTIPOINT(1010 502,1446 1018)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157322,0,GeomFromText("MULTIPOINT(1024 506,1443 1013)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157327,0,GeomFromText("MULTIPOINT(1079 481,1522 1003)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157327,1,GeomFromText("MULTIPOINT(1065 481,1528 1001)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157332,0,GeomFromText("MULTIPOINT(1252 455,1721 990)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157332,1,GeomFromText("MULTIPOINT(1236 448,1731 982)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157337,0,GeomFromText("MULTIPOINT(1463 396,1911 955)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157337,1,GeomFromText("MULTIPOINT(1462 413,1911 954)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (157417,0,GeomFromText("MULTIPOINT(282 689,520 900)", -1));
# ...
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180787,2,GeomFromText("MULTIPOINT(864 415,1109 810)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180792,2,GeomFromText("MULTIPOINT(1079 342,1357 882)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180797,2,GeomFromText("MULTIPOINT(1367 279,1673 905)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180862,3,GeomFromText("MULTIPOINT(748 751,776 821)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180877,3,GeomFromText("MULTIPOINT(864 749,894 815)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180887,3,GeomFromText("MULTIPOINT(953 744,986 809)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180947,1,GeomFromText("MULTIPOINT(380 640,705 923)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180947,0,GeomFromText("MULTIPOINT(39 655,382 920)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180952,1,GeomFromText("MULTIPOINT(577 631,918 965)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180952,0,GeomFromText("MULTIPOINT(184 601,587 936)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180957,1,GeomFromText("MULTIPOINT(853 581,1207 998)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (180962,1,GeomFromText("MULTIPOINT(1161 495,1696 1027)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181097,3,GeomFromText("MULTIPOINT(406 605,642 992)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181102,3,GeomFromText("MULTIPOINT(587 548,935 1035)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181107,3,GeomFromText("MULTIPOINT(878 476,1322 1061)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181112,3,GeomFromText("MULTIPOINT(1287 373,1872 890)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181122,1,GeomFromText("MULTIPOINT(903 843,997 918)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181122,3,GeomFromText("MULTIPOINT(1558 489,1819 997)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181127,1,GeomFromText("MULTIPOINT(978 843,1084 913)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181137,1,GeomFromText("MULTIPOINT(1173 833,1278 917)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181137,2,GeomFromText("MULTIPOINT(166 737,254 893)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181142,2,GeomFromText("MULTIPOINT(215 721,304 880)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181152,1,GeomFromText("MULTIPOINT(1519 818,1637 927)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181152,2,GeomFromText("MULTIPOINT(312 709,411 879)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181157,3,GeomFromText("MULTIPOINT(369 698,478 896)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181162,2,GeomFromText("MULTIPOINT(436 691,544 884)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181167,2,GeomFromText("MULTIPOINT(503 678,619 892)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181172,2,GeomFromText("MULTIPOINT(573 671,702 843)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181177,2,GeomFromText("MULTIPOINT(665 649,794 892)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181182,2,GeomFromText("MULTIPOINT(769 635,911 900)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181187,2,GeomFromText("MULTIPOINT(898 624,1030 901)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181187,2,GeomFromText("MULTIPOINT(1 647,191 1045)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181187,1,GeomFromText("MULTIPOINT(0 643,190 1049)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181192,2,GeomFromText("MULTIPOINT(69 611,353 952)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181197,2,GeomFromText("MULTIPOINT(254 577,562 1061)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181197,1,GeomFromText("MULTIPOINT(249 561,562 1059)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181202,2,GeomFromText("MULTIPOINT(1372 566,1578 915)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181202,1,GeomFromText("MULTIPOINT(510 519,836 947)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181202,1,GeomFromText("MULTIPOINT(0 671,165 915)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181207,2,GeomFromText("MULTIPOINT(1570 541,1806 921)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181207,2,GeomFromText("MULTIPOINT(62 641,302 931)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181207,1,GeomFromText("MULTIPOINT(868 451,1218 1009)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181212,1,GeomFromText("MULTIPOINT(184 626,452 1002)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181217,1,GeomFromText("MULTIPOINT(30 770,303 1019)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181217,1,GeomFromText("MULTIPOINT(365 561,665 1031)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181222,1,GeomFromText("MULTIPOINT(608 519,964 1055)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181222,1,GeomFromText("MULTIPOINT(177 749,451 1016)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181227,1,GeomFromText("MULTIPOINT(943 417,1413 1056)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181227,1,GeomFromText("MULTIPOINT(378 725,646 1063)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181232,1,GeomFromText("MULTIPOINT(680 701,901 1037)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181232,1,GeomFromText("MULTIPOINT(1437 288,1920 996)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181237,3,GeomFromText("MULTIPOINT(582 533,847 1012)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181242,3,GeomFromText("MULTIPOINT(883 462,1194 1032)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181242,1,GeomFromText("MULTIPOINT(1307 603,1896 1061)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181247,3,GeomFromText("MULTIPOINT(1297 354,1711 1007)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181247,1,GeomFromText("MULTIPOINT(363 422,800 968)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181357,1,GeomFromText("MULTIPOINT(641 793,809 908)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181402,2,GeomFromText("MULTIPOINT(41 734,115 805)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181407,2,GeomFromText("MULTIPOINT(59 720,121 793)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181412,1,GeomFromText("MULTIPOINT(76 718,136 780)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181417,2,GeomFromText("MULTIPOINT(1 703,60 805)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181422,1,GeomFromText("MULTIPOINT(79 713,173 818)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181432,2,GeomFromText("MULTIPOINT(86 693,171 805)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181437,2,GeomFromText("MULTIPOINT(187 712,307 827)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181442,2,GeomFromText("MULTIPOINT(0 645,179 855)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181442,1,GeomFromText("MULTIPOINT(0 642,179 860)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181447,2,GeomFromText("MULTIPOINT(36 629,232 846)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181447,2,GeomFromText("MULTIPOINT(300 692,430 820)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181452,2,GeomFromText("MULTIPOINT(143 595,294 791)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181452,2,GeomFromText("MULTIPOINT(312 616,411 806)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181462,2,GeomFromText("MULTIPOINT(254 549,472 816)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181467,1,GeomFromText("MULTIPOINT(0 560,297 989)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181472,1,GeomFromText("MULTIPOINT(52 500,411 966)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181477,1,GeomFromText("MULTIPOINT(198 445,635 1022)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181477,1,GeomFromText("MULTIPOINT(12 566,374 1014)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181477,2,GeomFromText("MULTIPOINT(643 430,918 763)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181482,1,GeomFromText("MULTIPOINT(399 364,889 1070)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181482,0,GeomFromText("MULTIPOINT(147 535,563 1037)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181487,0,GeomFromText("MULTIPOINT(345 475,627 1041)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181492,0,GeomFromText("MULTIPOINT(606 411,927 1053)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181497,0,GeomFromText("MULTIPOINT(242 655,444 819)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181497,1,GeomFromText("MULTIPOINT(919 320,1388 1016)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181502,0,GeomFromText("MULTIPOINT(825 742,1064 1026)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181502,1,GeomFromText("MULTIPOINT(1384 113,1920 1051)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181502,2,GeomFromText("MULTIPOINT(761 554,861 657)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181507,1,GeomFromText("MULTIPOINT(626 614,774 777)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181507,0,GeomFromText("MULTIPOINT(1131 733,1397 1021)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181512,2,GeomFromText("MULTIPOINT(911 511,1083 703)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181517,1,GeomFromText("MULTIPOINT(1043 484,1198 709)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181522,1,GeomFromText("MULTIPOINT(768 514,1083 798)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181527,2,GeomFromText("MULTIPOINT(1322 412,1501 759)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181532,1,GeomFromText("MULTIPOINT(1177 417,1589 773)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181537,1,GeomFromText("MULTIPOINT(1468 329,1920 794)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181552,4,GeomFromText("MULTIPOINT(1799 558,1833 682)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181607,1,GeomFromText("MULTIPOINT(1044 721,1134 817)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181612,1,GeomFromText("MULTIPOINT(1105 713,1224 820)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181672,2,GeomFromText("MULTIPOINT(199 767,250 824)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181682,2,GeomFromText("MULTIPOINT(130 792,160 824)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181687,2,GeomFromText("MULTIPOINT(168 772,220 838)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181687,1,GeomFromText("MULTIPOINT(169 771,219 836)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181692,1,GeomFromText("MULTIPOINT(163 768,227 836)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181697,2,GeomFromText("MULTIPOINT(161 764,226 831)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181697,1,GeomFromText("MULTIPOINT(161 763,226 830)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181702,1,GeomFromText("MULTIPOINT(173 760,232 827)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181702,2,GeomFromText("MULTIPOINT(174 762,231 827)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181707,2,GeomFromText("MULTIPOINT(172 753,235 820)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181712,1,GeomFromText("MULTIPOINT(172 754,236 826)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181717,2,GeomFromText("MULTIPOINT(359 760,408 808)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181717,1,GeomFromText("MULTIPOINT(170 748,235 821)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181722,2,GeomFromText("MULTIPOINT(358 758,408 804)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181722,1,GeomFromText("MULTIPOINT(165 746,231 821)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181727,2,GeomFromText("MULTIPOINT(349 760,407 811)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181727,2,GeomFromText("MULTIPOINT(97 791,135 822)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181727,1,GeomFromText("MULTIPOINT(158 748,225 824)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181732,2,GeomFromText("MULTIPOINT(342 761,401 811)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181732,1,GeomFromText("MULTIPOINT(155 752,217 820)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181732,1,GeomFromText("MULTIPOINT(94 791,129 821)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181737,2,GeomFromText("MULTIPOINT(337 759,396 812)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181737,2,GeomFromText("MULTIPOINT(149 750,212 825)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181742,2,GeomFromText("MULTIPOINT(333 760,392 816)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181742,1,GeomFromText("MULTIPOINT(146 747,206 822)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181747,2,GeomFromText("MULTIPOINT(333 760,392 817)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181747,1,GeomFromText("MULTIPOINT(144 750,205 822)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181752,2,GeomFromText("MULTIPOINT(334 757,390 812)", -1));
# INSERT OR IGNORE INTO trees(frame_id,damage_index,geometry) VALUES (181752,1,GeomFromText("MULTIPOINT(137 746,204 819)", -1));
