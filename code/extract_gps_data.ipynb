# %% [markdown]
# # extract_gps_data.ipynb
#
# * 2021-05-06 Added code to adjust coordinates using rolling averages
# * 2021-05-02 First version by Aubrey Moore
#
# Extracts geotagging data from EXIF tags stored in one or more image files.
#
# Example usage:
#
#     papermill extract_gps_data.ipynb \
#     '../open-camera-test/home-uog/extract_gps_data_output.ipynb' \
#     -p IMAGE_FILE_PATH '../open-camera-test/home-uog/*.jpg' \
#     -p CSV_OUTPUT_FILE '../open-camera-test/home-uog/gps-data.csv'
#
# When the above command line is executed in the directory containing **extract_gps_data.ipynb**,
# GPS data will be extracted from all **jpg** files in the **../open-camera-test/home-uog** directory
# and will be saved **../open-camera-test/home-uog/gps-data.csv**.
#
# ## References
#
# https://developer.here.com/blog/getting-started-with-geocoding-exif-image-metadata-in-python3
#
# http://www.50northspatial.org/using-open-camera-geotagging-photos/

# %%
from PIL import Image
from PIL.ExifTags import TAGS, GPSTAGS
import glob
import pandas as pd
import os
import plotly.express as px
import numpy as np
import logging

# %%
# parameters for papermill

IMAGE_FILE_PATH = '../2021-05-14/*.jpg'         # Path to one or more image files. Can include wildcards. See https://pymotw.com/2/glob/ for pattern matching details.
CSV_OUTPUT_FILE = '../2021-05-14/gps-data.csv'  # Path to a CSV file where the GPS data will be stored. 
ADJUST_COORDINATES = True
MAKE_MAPS = True

# %%
def get_exif(filename):
    image = Image.open(filename)
    image.verify()
    return image._getexif()


def get_geotagging(exif):
    if not exif:
        raise ValueError("No EXIF metadata found")
    geotagging = {}
    for (idx, tag) in TAGS.items():
        if tag == 'GPSInfo':
            if idx not in exif:
                raise ValueError("No EXIF geotagging found")
            for (key, val) in GPSTAGS.items():
                if key in exif[idx]:
                    geotagging[val] = exif[idx][key]
    return geotagging


def get_gps_coordinates(image_file_name):
    exif = get_exif(image_file_name)
    gpsdata = get_geotagging(exif)
        
    d,m,s = gpsdata['GPSLatitude']
    latitude = d + m/60.0 + s/3600.0
    if gpsdata['GPSLatitudeRef']=='S':
        latitude = -latitude
    latitude = round(latitude, 6)

    d,m,s = gpsdata['GPSLongitude']
    longitude = d + m/60.0 + s/3600.0
    if gpsdata['GPSLongitudeRef']=='W':
        longitude = -longitude
    longitude = round(longitude, 6)
    
    date = gpsdata['GPSDateStamp']
    date = date.replace(':', '-')
    h, m, s = gpsdata['GPSTimeStamp']
    timestamp = f'{date} {int(h):02}:{int(m):02}:{int(s):02}'
    return longitude,latitude, timestamp

def create_dataframe():
    # Get a sorted list of image files
    image_files = sorted(glob.glob(IMAGE_FILE_PATH))
    n = len(image_files)

    # Extract coordinates from each image file
    df = pd.DataFrame(columns=['imagefile','longitude','latitude','timestamp'])
    for i, image_file in enumerate(image_files):
        longitude, latitude, timestamp = get_gps_coordinates(image_file)
        df = df.append({'imagefile':os.path.basename(image_file),
                        'longitude':longitude,
                        'latitude':latitude,
                        'timestamp':pd.to_datetime(timestamp)}, ignore_index=True) 
        if ((i+1) % 100 == 0):
            logging.info(f'{i+1} of {n} images processed')
    return df 


def adjust_gps_coordinates():
    '''
    Calculates rolling averages for latitude and longitude to get better estimates for camera 
    positions and saves them in new columns: longitude_adjusted and latitude_adjusted. 
    This is a work-a-round for low precision GPS EXIF data data saved by the 
    OpenCamera app. For some reason, the app saves only degrees, minutes and seconds without decimal places. 
    This notebook calculates new points using 5-point rolling averages of latitude and longitude. 
    '''
    df['time_diff'] = df["timestamp"].diff().apply(lambda x: x/np.timedelta64(1,'s')).fillna(0).astype('int64')
    
    # Find location of segment breaks
    # A new segment begins when an (image is taken is more than 60s after previous image

    segments = []
    segment_breaks = df.index[df['time_diff'] > 60].tolist()
    segment_breaks.append(df.shape[0]) # Last index plus 1
    for i, segment_break in enumerate(segment_breaks):
        if i == 0:
            start = 0
        else:
            start = segment_breaks[i-1]
        segments.append({'first_index': start, 'last_index': segment_break-1})
    logging.info(f'segments: {segments}')

    # Calculate rolling averages to locations within each segment
    
#     df['longitude_adjusted'] = 0
#     df['latitude_adjusted'] = 0
        
    for segment in segments:
#         df.loc[segment['first_index']:(segment['last_index']+1)]['longitude_adjusted'] = df.loc[segment['first_index']:(segment['last_index']+1)]['longitude'].rolling(5, center=True, min_periods=1).mean() 
#         df.loc[segment['first_index']:(segment['last_index']+1)]['latitude_adjusted'] = df.loc[segment['first_index']:(segment['last_index']+1)]['latitude'].rolling(5, center=True, min_periods=1).mean() 
        i1 = segment['first_index']
        i2 = segment['last_index']
        df.loc[i1:i2, 'longitude_adjusted'] = df.loc[i1:i2, 'longitude'].rolling(5, center=True, min_periods=1).mean() 
        df.loc[i1:i2, 'latitude_adjusted'] = df.loc[i1:i2, 'latitude'].rolling(5, center=True, min_periods=1).mean() 
        
#     df['longitude_adjusted'] = df['longitude'].rolling(5, center=True, min_periods=1).mean() 
#     df['latitude_adjusted'] = df['latitude'].rolling(5, center=True, min_periods=1).mean() 
    
    return

# %%
# MAIN

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(funcName)s %(message)s",
    datefmt="%Y-%m-%dT%H:%M:%S%z",
    handlers=[logging.StreamHandler()])
logging.info('Starting georef.py')

df = create_dataframe()

if ADJUST_COORDINATES:
    logging.info('Adjusting coordinates')
    adjust_gps_coordinates()
    
df.to_csv(CSV_OUTPUT_FILE, index=False)
logging.info(f'FINISHED: Data saved in {CSV_OUTPUT_FILE}')
# Out:
# 2021-05-18T13:05:32+1000 [INFO] <module> Starting georef.py
# 2021-05-18T13:05:32+1000 [INFO] create_dataframe 100 of 13525 images processed
# 2021-05-18T13:05:33+1000 [INFO] create_dataframe 200 of 13525 images processed
# 2021-05-18T13:05:33+1000 [INFO] create_dataframe 300 of 13525 images processed
# 2021-05-18T13:05:33+1000 [INFO] create_dataframe 400 of 13525 images processed
# 2021-05-18T13:05:34+1000 [INFO] create_dataframe 500 of 13525 images processed
# 2021-05-18T13:05:34+1000 [INFO] create_dataframe 600 of 13525 images processed
# 2021-05-18T13:05:34+1000 [INFO] create_dataframe 700 of 13525 images processed
# 2021-05-18T13:05:34+1000 [INFO] create_dataframe 800 of 13525 images processed
# 2021-05-18T13:05:35+1000 [INFO] create_dataframe 900 of 13525 images processed
# 2021-05-18T13:05:35+1000 [INFO] create_dataframe 1000 of 13525 images processed
# 2021-05-18T13:05:35+1000 [INFO] create_dataframe 1100 of 13525 images processed
# 2021-05-18T13:05:36+1000 [INFO] create_dataframe 1200 of 13525 images processed
# 2021-05-18T13:05:36+1000 [INFO] create_dataframe 1300 of 13525 images processed
# 2021-05-18T13:05:36+1000 [INFO] create_dataframe 1400 of 13525 images processed
# 2021-05-18T13:05:37+1000 [INFO] create_dataframe 1500 of 13525 images processed
# 2021-05-18T13:05:37+1000 [INFO] create_dataframe 1600 of 13525 images processed
# 2021-05-18T13:05:37+1000 [INFO] create_dataframe 1700 of 13525 images processed
# 2021-05-18T13:05:37+1000 [INFO] create_dataframe 1800 of 13525 images processed
# 2021-05-18T13:05:38+1000 [INFO] create_dataframe 1900 of 13525 images processed
# 2021-05-18T13:05:38+1000 [INFO] create_dataframe 2000 of 13525 images processed
# 2021-05-18T13:05:38+1000 [INFO] create_dataframe 2100 of 13525 images processed
# 2021-05-18T13:05:39+1000 [INFO] create_dataframe 2200 of 13525 images processed
# 2021-05-18T13:05:39+1000 [INFO] create_dataframe 2300 of 13525 images processed
# 2021-05-18T13:05:39+1000 [INFO] create_dataframe 2400 of 13525 images processed
# 2021-05-18T13:05:39+1000 [INFO] create_dataframe 2500 of 13525 images processed
# 2021-05-18T13:05:40+1000 [INFO] create_dataframe 2600 of 13525 images processed
# 2021-05-18T13:05:40+1000 [INFO] create_dataframe 2700 of 13525 images processed
# 2021-05-18T13:05:40+1000 [INFO] create_dataframe 2800 of 13525 images processed
# 2021-05-18T13:05:41+1000 [INFO] create_dataframe 2900 of 13525 images processed
# 2021-05-18T13:05:41+1000 [INFO] create_dataframe 3000 of 13525 images processed
# 2021-05-18T13:05:41+1000 [INFO] create_dataframe 3100 of 13525 images processed
# 2021-05-18T13:05:42+1000 [INFO] create_dataframe 3200 of 13525 images processed
# 2021-05-18T13:05:42+1000 [INFO] create_dataframe 3300 of 13525 images processed
# 2021-05-18T13:05:42+1000 [INFO] create_dataframe 3400 of 13525 images processed
# 2021-05-18T13:05:43+1000 [INFO] create_dataframe 3500 of 13525 images processed
# 2021-05-18T13:05:43+1000 [INFO] create_dataframe 3600 of 13525 images processed
# 2021-05-18T13:05:43+1000 [INFO] create_dataframe 3700 of 13525 images processed
# 2021-05-18T13:05:44+1000 [INFO] create_dataframe 3800 of 13525 images processed
# 2021-05-18T13:05:44+1000 [INFO] create_dataframe 3900 of 13525 images processed
# 2021-05-18T13:05:44+1000 [INFO] create_dataframe 4000 of 13525 images processed
# 2021-05-18T13:05:45+1000 [INFO] create_dataframe 4100 of 13525 images processed
# 2021-05-18T13:05:45+1000 [INFO] create_dataframe 4200 of 13525 images processed
# 2021-05-18T13:05:45+1000 [INFO] create_dataframe 4300 of 13525 images processed
# 2021-05-18T13:05:45+1000 [INFO] create_dataframe 4400 of 13525 images processed
# 2021-05-18T13:05:46+1000 [INFO] create_dataframe 4500 of 13525 images processed
# 2021-05-18T13:05:46+1000 [INFO] create_dataframe 4600 of 13525 images processed
# 2021-05-18T13:05:46+1000 [INFO] create_dataframe 4700 of 13525 images processed
# 2021-05-18T13:05:47+1000 [INFO] create_dataframe 4800 of 13525 images processed
# 2021-05-18T13:05:47+1000 [INFO] create_dataframe 4900 of 13525 images processed
# 2021-05-18T13:05:47+1000 [INFO] create_dataframe 5000 of 13525 images processed
# 2021-05-18T13:05:48+1000 [INFO] create_dataframe 5100 of 13525 images processed
# 2021-05-18T13:05:48+1000 [INFO] create_dataframe 5200 of 13525 images processed
# 2021-05-18T13:05:48+1000 [INFO] create_dataframe 5300 of 13525 images processed
# 2021-05-18T13:05:48+1000 [INFO] create_dataframe 5400 of 13525 images processed
# 2021-05-18T13:05:49+1000 [INFO] create_dataframe 5500 of 13525 images processed
# 2021-05-18T13:05:49+1000 [INFO] create_dataframe 5600 of 13525 images processed
# 2021-05-18T13:05:49+1000 [INFO] create_dataframe 5700 of 13525 images processed
# 2021-05-18T13:05:50+1000 [INFO] create_dataframe 5800 of 13525 images processed
# 2021-05-18T13:05:50+1000 [INFO] create_dataframe 5900 of 13525 images processed
# 2021-05-18T13:05:50+1000 [INFO] create_dataframe 6000 of 13525 images processed
# 2021-05-18T13:05:51+1000 [INFO] create_dataframe 6100 of 13525 images processed
# 2021-05-18T13:05:51+1000 [INFO] create_dataframe 6200 of 13525 images processed
# 2021-05-18T13:05:51+1000 [INFO] create_dataframe 6300 of 13525 images processed
# 2021-05-18T13:05:51+1000 [INFO] create_dataframe 6400 of 13525 images processed
# 2021-05-18T13:05:52+1000 [INFO] create_dataframe 6500 of 13525 images processed
# 2021-05-18T13:05:52+1000 [INFO] create_dataframe 6600 of 13525 images processed
# 2021-05-18T13:05:52+1000 [INFO] create_dataframe 6700 of 13525 images processed
# 2021-05-18T13:05:53+1000 [INFO] create_dataframe 6800 of 13525 images processed
# 2021-05-18T13:05:53+1000 [INFO] create_dataframe 6900 of 13525 images processed
# 2021-05-18T13:05:53+1000 [INFO] create_dataframe 7000 of 13525 images processed
# 2021-05-18T13:05:54+1000 [INFO] create_dataframe 7100 of 13525 images processed
# 2021-05-18T13:05:54+1000 [INFO] create_dataframe 7200 of 13525 images processed
# 2021-05-18T13:05:54+1000 [INFO] create_dataframe 7300 of 13525 images processed
# 2021-05-18T13:05:55+1000 [INFO] create_dataframe 7400 of 13525 images processed
# 2021-05-18T13:05:55+1000 [INFO] create_dataframe 7500 of 13525 images processed
# 2021-05-18T13:05:55+1000 [INFO] create_dataframe 7600 of 13525 images processed
# 2021-05-18T13:05:55+1000 [INFO] create_dataframe 7700 of 13525 images processed
# 2021-05-18T13:05:56+1000 [INFO] create_dataframe 7800 of 13525 images processed
# 2021-05-18T13:05:56+1000 [INFO] create_dataframe 7900 of 13525 images processed
# 2021-05-18T13:05:56+1000 [INFO] create_dataframe 8000 of 13525 images processed
# 2021-05-18T13:05:57+1000 [INFO] create_dataframe 8100 of 13525 images processed
# 2021-05-18T13:05:57+1000 [INFO] create_dataframe 8200 of 13525 images processed
# 2021-05-18T13:05:57+1000 [INFO] create_dataframe 8300 of 13525 images processed
# 2021-05-18T13:05:58+1000 [INFO] create_dataframe 8400 of 13525 images processed
# 2021-05-18T13:05:58+1000 [INFO] create_dataframe 8500 of 13525 images processed
# 2021-05-18T13:05:58+1000 [INFO] create_dataframe 8600 of 13525 images processed
# 2021-05-18T13:05:58+1000 [INFO] create_dataframe 8700 of 13525 images processed
# 2021-05-18T13:05:59+1000 [INFO] create_dataframe 8800 of 13525 images processed
# 2021-05-18T13:05:59+1000 [INFO] create_dataframe 8900 of 13525 images processed
# 2021-05-18T13:05:59+1000 [INFO] create_dataframe 9000 of 13525 images processed
# 2021-05-18T13:06:00+1000 [INFO] create_dataframe 9100 of 13525 images processed
# 2021-05-18T13:06:00+1000 [INFO] create_dataframe 9200 of 13525 images processed
# 2021-05-18T13:06:00+1000 [INFO] create_dataframe 9300 of 13525 images processed
# 2021-05-18T13:06:01+1000 [INFO] create_dataframe 9400 of 13525 images processed
# 2021-05-18T13:06:01+1000 [INFO] create_dataframe 9500 of 13525 images processed
# 2021-05-18T13:06:01+1000 [INFO] create_dataframe 9600 of 13525 images processed
# 2021-05-18T13:06:02+1000 [INFO] create_dataframe 9700 of 13525 images processed
# 2021-05-18T13:06:02+1000 [INFO] create_dataframe 9800 of 13525 images processed
# 2021-05-18T13:06:02+1000 [INFO] create_dataframe 9900 of 13525 images processed
# 2021-05-18T13:06:02+1000 [INFO] create_dataframe 10000 of 13525 images processed
# 2021-05-18T13:06:03+1000 [INFO] create_dataframe 10100 of 13525 images processed
# 2021-05-18T13:06:03+1000 [INFO] create_dataframe 10200 of 13525 images processed
# 2021-05-18T13:06:03+1000 [INFO] create_dataframe 10300 of 13525 images processed
# 2021-05-18T13:06:04+1000 [INFO] create_dataframe 10400 of 13525 images processed
# 2021-05-18T13:06:04+1000 [INFO] create_dataframe 10500 of 13525 images processed
# 2021-05-18T13:06:04+1000 [INFO] create_dataframe 10600 of 13525 images processed
# 2021-05-18T13:06:05+1000 [INFO] create_dataframe 10700 of 13525 images processed
# 2021-05-18T13:06:05+1000 [INFO] create_dataframe 10800 of 13525 images processed
# 2021-05-18T13:06:05+1000 [INFO] create_dataframe 10900 of 13525 images processed
# 2021-05-18T13:06:06+1000 [INFO] create_dataframe 11000 of 13525 images processed
# 2021-05-18T13:06:06+1000 [INFO] create_dataframe 11100 of 13525 images processed
# 2021-05-18T13:06:06+1000 [INFO] create_dataframe 11200 of 13525 images processed
# 2021-05-18T13:06:06+1000 [INFO] create_dataframe 11300 of 13525 images processed
# 2021-05-18T13:06:07+1000 [INFO] create_dataframe 11400 of 13525 images processed
# 2021-05-18T13:06:07+1000 [INFO] create_dataframe 11500 of 13525 images processed
# 2021-05-18T13:06:07+1000 [INFO] create_dataframe 11600 of 13525 images processed
# 2021-05-18T13:06:08+1000 [INFO] create_dataframe 11700 of 13525 images processed
# 2021-05-18T13:06:08+1000 [INFO] create_dataframe 11800 of 13525 images processed
# 2021-05-18T13:06:08+1000 [INFO] create_dataframe 11900 of 13525 images processed
# 2021-05-18T13:06:09+1000 [INFO] create_dataframe 12000 of 13525 images processed
# 2021-05-18T13:06:09+1000 [INFO] create_dataframe 12100 of 13525 images processed
# 2021-05-18T13:06:09+1000 [INFO] create_dataframe 12200 of 13525 images processed
# 2021-05-18T13:06:09+1000 [INFO] create_dataframe 12300 of 13525 images processed
# 2021-05-18T13:06:10+1000 [INFO] create_dataframe 12400 of 13525 images processed
# 2021-05-18T13:06:10+1000 [INFO] create_dataframe 12500 of 13525 images processed
# 2021-05-18T13:06:10+1000 [INFO] create_dataframe 12600 of 13525 images processed
# 2021-05-18T13:06:11+1000 [INFO] create_dataframe 12700 of 13525 images processed
# 2021-05-18T13:06:11+1000 [INFO] create_dataframe 12800 of 13525 images processed
# 2021-05-18T13:06:11+1000 [INFO] create_dataframe 12900 of 13525 images processed
# 2021-05-18T13:06:12+1000 [INFO] create_dataframe 13000 of 13525 images processed
# 2021-05-18T13:06:12+1000 [INFO] create_dataframe 13100 of 13525 images processed
# 2021-05-18T13:06:12+1000 [INFO] create_dataframe 13200 of 13525 images processed
# 2021-05-18T13:06:12+1000 [INFO] create_dataframe 13300 of 13525 images processed
# 2021-05-18T13:06:13+1000 [INFO] create_dataframe 13400 of 13525 images processed
# 2021-05-18T13:06:13+1000 [INFO] create_dataframe 13500 of 13525 images processed
# 2021-05-18T13:06:13+1000 [INFO] <module> Adjusting coordinates
# 2021-05-18T13:06:13+1000 [INFO] adjust_gps_coordinates segments: [{'first_index': 0, 'last_index': 4757}, {'first_index': 4758, 'last_index': 13524}]
# 2021-05-18T13:06:13+1000 [INFO] <module> FINISHED: Data saved in ../2021-05-14/gps-data.csv

# %%
df
# Out:
#                      imagefile   longitude   latitude           timestamp  \
# 0      IMG_20210514_093415.jpg  144.802500  13.448056 2021-05-13 23:34:15
# 1      IMG_20210514_093416.jpg  144.802500  13.448056 2021-05-13 23:34:16
# 2      IMG_20210514_093417.jpg  144.802500  13.448056 2021-05-13 23:34:17
# 3      IMG_20210514_093418.jpg  144.802500  13.448056 2021-05-13 23:34:18
# 4      IMG_20210514_093419.jpg  144.802500  13.448056 2021-05-13 23:34:19
# ...                        ...         ...        ...                 ...
# 13520  IMG_20210514_150918.jpg  144.801667  13.464167 2021-05-14 05:09:18
# 13521  IMG_20210514_150919.jpg  144.801667  13.464167 2021-05-14 05:09:19
# 13522  IMG_20210514_150920.jpg  144.801667  13.464167 2021-05-14 05:09:20
# 13523  IMG_20210514_150921.jpg  144.801667  13.464167 2021-05-14 05:09:21
# 13524  IMG_20210514_150922.jpg  144.801667  13.464167 2021-05-14 05:09:22
#
#        time_diff  longitude_adjusted  latitude_adjusted
# 0              0          144.802500          13.448056
# 1              1          144.802500          13.448056
# 2              1          144.802500          13.448056
# 3              1          144.802500          13.448056
# 4              1          144.802500          13.448056
# ...          ...                 ...                ...
# 13520          1          144.801667          13.464167
# 13521          1          144.801667          13.464167
# 13522          1          144.801667          13.464167
# 13523          1          144.801667          13.464167
# 13524          1          144.801667          13.464167
#
# [13525 rows x 7 columns]

# %%
if MAKE_MAPS:
    fig = px.scatter_mapbox(df, lat="latitude", lon="longitude", title='Original coordinates', zoom=9)
    fig.update_layout(mapbox_style="open-street-map", margin={"r":0,"t":30,"l":0,"b":0})
    fig.show()
# Out:
# <div>                            <div id="0b68f0c5-73f3-44c9-9a2e-4afb5e1df7a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b68f0c5-73f3-44c9-9a2e-4afb5e1df7a9")) {                    Plotly.newPlot(                        "0b68f0c5-73f3-44c9-9a2e-4afb5e1df7a9",                        [{"hovertemplate": "latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "lat": [13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448333, 13.448611, 13.448611, 13.448611, 13.448611, 13.448611, 13.448889, 13.448889, 13.449167, 13.449167, 13.449167, 13.449167, 13.449444, 13.449444, 13.449444, 13.449444, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449444, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.45, 13.45, 13.45, 13.45, 13.45, 13.45, 13.450278, 13.450278, 13.450278, 13.450278, 13.450278, 13.450556, 13.450556, 13.450556, 13.450556, 13.450556, 13.450556, 13.450833, 13.450833, 13.450833, 13.450833, 13.450833, 13.451111, 13.451111, 13.451111, 13.451389, 13.451389, 13.451389, 13.451667, 13.451667, 13.451667, 13.451944, 13.451944, 13.452222, 13.452222, 13.4525, 13.4525, 13.452778, 13.452778, 13.453056, 13.453333, 13.453333, 13.453611, 13.453611, 13.453889, 13.453889, 13.454167, 13.454167, 13.454444, 13.454722, 13.455, 13.455, 13.455278, 13.455556, 13.455556, 13.455833, 13.455833, 13.456111, 13.456111, 13.456389, 13.456667, 13.456667, 13.456944, 13.456944, 13.457222, 13.457222, 13.4575, 13.4575, 13.457778, 13.458056, 13.458056, 13.458333, 13.458333, 13.458611, 13.458611, 13.458889, 13.458889, 13.459167, 13.459444, 13.459444, 13.459722, 13.459722, 13.46, 13.46, 13.460278, 13.460278, 13.460556, 13.460556, 13.460556, 13.460833, 13.460833, 13.460833, 13.461111, 13.461111, 13.461389, 13.461389, 13.461389, 13.461389, 13.461667, 13.461667, 13.461667, 13.461944, 13.461944, 13.462222, 13.462222, 13.462222, 13.462222, 13.4625, 13.4625, 13.462778, 13.462778, 13.462778, 13.463056, 13.463056, 13.4633 ...

# %%
if MAKE_MAPS and ADJUST_COORDINATES:
    fig = px.scatter_mapbox(df, lat="latitude_adjusted", lon="longitude_adjusted", 
                            title='Adjusted coordinates', zoom=9)
    fig.update_layout(mapbox_style="open-street-map", margin={"r":0,"t":30,"l":0,"b":0})
    fig.show()
# Out:
# <div>                            <div id="7768b552-c056-4e39-ae75-af80e7684154" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7768b552-c056-4e39-ae75-af80e7684154")) {                    Plotly.newPlot(                        "7768b552-c056-4e39-ae75-af80e7684154",                        [{"hovertemplate": "latitude_adjusted=%{lat}<br>longitude_adjusted=%{lon}<extra></extra>", "lat": [13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448056, 13.448111400000002, 13.448166800000005, 13.448222200000007, 13.448277600000008, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44833300000001, 13.44838860000001, 13.448444200000008, 13.448499800000008, 13.448555400000007, 13.448611000000005, 13.448666600000005, 13.448722200000002, 13.448833400000003, 13.448944600000004, 13.449055800000005, 13.449111400000007, 13.449222400000007, 13.449277800000008, 13.449333200000007, 13.449388600000006, 13.449499600000005, 13.449555200000002, 13.449610800000002, 13.449666400000002, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449722, 13.449666400000002, 13.449610800000002, 13.449555200000002, 13.449499600000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449444000000005, 13.449499600000005, 13.449555200000002, 13.449610800000002, 13.449666400000002, 13.449722, 13.449722, 13.4497776, 13.449833200000004, 13.449888800000005, 13.449944400000007, 13.450000000000008, 13.450000000000008, 13.450055600000008, 13.450111200000006, 13.450166800000005, 13.450222400000005, 13.450278000000003, 13.450333600000004, 13.450389200000007, 13.450444800000009, 13.45050040000001, 13.450556000000011, 13.450556000000011, 13.45061140000001, 13. ...
